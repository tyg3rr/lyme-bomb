# %%
import pandas as pd

# %%
rain_df = pd.read_csv("C:\\Users\\ljens\\OneDrive\\Documents\\APHA\\annual precip MI.csv")

# %%
rain_df.head()
# Out:
#           ID    Date  Value
# 0  Alcona     200001   1.37
# 1  Alcona     200002   1.69
# 2  Alcona     200003   0.90
# 3  Alcona     200004   2.32
# 4  Alcona     200005   4.56

# %%
rain_df['Date'].apply(lambda x: str(x)[0:4])
# Out:
# 0        2000
# 1        2000
# 2        2000
# 3        2000
# 4        2000
#          ...
# 22156    2021
# 22157    2021
# 22158    2022
# 22159    2022
# 22160    2022
# Name: Date, Length: 22161, dtype: object

# %%
rain_df['Year'] = rain_df['Date'].apply(lambda x: str(x)[0:4])

# %%
rain_df
# Out:
#                ID    Date  Value  Year
# 0       Alcona     200001   1.37  2000
# 1       Alcona     200002   1.69  2000
# 2       Alcona     200003   0.90  2000
# 3       Alcona     200004   2.32  2000
# 4       Alcona     200005   4.56  2000
# ...           ...     ...    ...   ...
# 22156  Wexford     202111   1.67  2021
# 22157  Wexford     202112   2.71  2021
# 22158  Wexford     202201   0.87  2022
# 22159  Wexford     202202   1.16  2022
# 22160  Wexford     202203   4.29  2022
#
# [22161 rows x 4 columns]

# %%
rain_df['Year'] = rain_df['Year'].astype('int')

# %%
rain_df.describe()
# Out:
#                 Date         Value          Year
# count   22161.000000  22161.000000  22161.000000
# mean   201069.370787      2.880005   2010.629213
# std       642.328393      1.509697      6.424085
# min    200001.000000      0.080000   2000.000000
# 25%    200507.000000      1.790000   2005.000000
# 50%    201102.000000      2.640000   2011.000000
# 75%    201609.000000      3.690000   2016.000000
# max    202203.000000     12.050000   2022.000000

# %%
rain_df
# Out:
#                ID    Date  Value  Year
# 0       Alcona     200001   1.37  2000
# 1       Alcona     200002   1.69  2000
# 2       Alcona     200003   0.90  2000
# 3       Alcona     200004   2.32  2000
# 4       Alcona     200005   4.56  2000
# ...           ...     ...    ...   ...
# 22156  Wexford     202111   1.67  2021
# 22157  Wexford     202112   2.71  2021
# 22158  Wexford     202201   0.87  2022
# 22159  Wexford     202202   1.16  2022
# 22160  Wexford     202203   4.29  2022
#
# [22161 rows x 4 columns]

# %%
df = pd.DataFrame(rain_df.groupby([rain_df['ID'], rain_df['Year']])['Value'].sum())

# %%
df
# Out:
#                  Value
# ID         Year
# Alcona     2000  28.97
#            2001  28.54
#            2002  26.73
#            2003  28.95
#            2004  30.72
# ...                ...
# Wexford    2018  33.19
#            2019  44.29
#            2020  35.77
#            2021  36.68
#            2022   6.32
#
# [1909 rows x 1 columns]

# %%
main_df = pd.read_csv("C:\\Users\\ljens\\OneDrive\\Documents\\MSU MPH\\889\\889 final work\\MAIN_4-21.csv")

# %%
main_df.head()
# Out:
#    Unnamed: 0      ID  TIME  Lyme Disease Cases  Incidence  Extreme Heat Days  \
# 0           0  Alcona  2000                   0        0.0                  7
# 1           1  Alcona  2001                   0        0.0                 19
# 2           2  Alcona  2002                   0        0.0                 25
# 3           3  Alcona  2003                   0        0.0                 11
# 4           4  Alcona  2004                   0        0.0                  7
#
#    Floods      Rain   Temp (F)   Pop.  Ticks  Forest Cover
# 0       2  2.414167  44.050000  11677    1.0           NaN
# 1       4  2.378333  46.150000  11665    1.0          56.3
# 2       3  2.227500  45.125000  11480    0.0           NaN
# 3       3  2.412500  43.075000  11495    1.0           NaN
# 4       4  2.560000  43.766667  11459    1.0           NaN

# %%
main_df.drop(columns = 'Unnamed: 0', inplace=True)

# %%
main_df
# Out:
#            ID  TIME  Lyme Disease Cases  Incidence  Extreme Heat Days  Floods  \
# 0      Alcona  2000                   0   0.000000                  7       2
# 1      Alcona  2001                   0   0.000000                 19       4
# 2      Alcona  2002                   0   0.000000                 25       3
# 3      Alcona  2003                   0   0.000000                 11       3
# 4      Alcona  2004                   0   0.000000                  7       4
# ...       ...   ...                 ...        ...                ...     ...
# 1655  Wexford  2015                   0   0.000000                 13       4
# 1656  Wexford  2016                   0   0.000000                 30       4
# 1657  Wexford  2017                   0   0.000000                 10       7
# 1658  Wexford  2018                   0   0.000000                 34       3
# 1659  Wexford  2019                   1   0.311478                  5       6
#
# ...

# %%
main_df.rename(columns = {'Lyme Disease Cases':'Cases', 'Extreme Heat Days':'Extreme Heat', 'Floods':'Extreme Precip.', 'Rain':'Average Monthly Rainfall', 'Temp (F)':'Average Temp (F)', 'Forest Cover':'Forest Cover (%)', 'Ticks':'Reported Ticks'}, inplace=True)

# %%
main_df.head()
# Out:
#        ID  TIME  Cases  Incidence  Extreme Heat  Extreme Precip.  \
# 0  Alcona  2000      0        0.0             7                2
# 1  Alcona  2001      0        0.0            19                4
# 2  Alcona  2002      0        0.0            25                3
# 3  Alcona  2003      0        0.0            11                3
# 4  Alcona  2004      0        0.0             7                4
#
#    Average Monthly Rainfall  Average Temp (F)   Pop.  Reported Ticks  \
# 0                  2.414167         44.050000  11677             1.0
# 1                  2.378333         46.150000  11665             1.0
# 2                  2.227500         45.125000  11480             0.0
# 3                  2.412500         43.075000  11495             1.0
# 4                  2.560000         43.766667  11459             1.0
#
#    Forest Cover (%)
# 0               NaN
# 1              56.3
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df.head()
# Out:
#                 Value
# ID        Year
# Alcona    2000  28.97
#           2001  28.54
#           2002  26.73
#           2003  28.95
#           2004  30.72

# %%
df.rename(columns = {'Year':'TIME', 'Value':'Total Rainfall'}, inplace=True)

# %%
df.head()
# Out:
#                 Total Rainfall
# ID        Year
# Alcona    2000           28.97
#           2001           28.54
#           2002           26.73
#           2003           28.95
#           2004           30.72

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#           ID  Year  Total Rainfall
# 0  Alcona     2000           28.97
# 1  Alcona     2001           28.54
# 2  Alcona     2002           26.73
# 3  Alcona     2003           28.95
# 4  Alcona     2004           30.72

# %%
main_df.head()
# Out:
#        ID  TIME  Cases  Incidence  Extreme Heat  Extreme Precip.  \
# 0  Alcona  2000      0        0.0             7                2
# 1  Alcona  2001      0        0.0            19                4
# 2  Alcona  2002      0        0.0            25                3
# 3  Alcona  2003      0        0.0            11                3
# 4  Alcona  2004      0        0.0             7                4
#
#    Average Monthly Rainfall  Average Temp (F)   Pop.  Reported Ticks  \
# 0                  2.414167         44.050000  11677             1.0
# 1                  2.378333         46.150000  11665             1.0
# 2                  2.227500         45.125000  11480             0.0
# 3                  2.412500         43.075000  11495             1.0
# 4                  2.560000         43.766667  11459             1.0
#
#    Forest Cover (%)
# 0               NaN
# 1              56.3
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df.describe()
# Out:
#               Year  Total Rainfall
# count  1909.000000     1909.000000
# mean   2011.000000       33.433106
# std       6.634988        7.608103
# min    2000.000000        3.970000
# 25%    2005.000000       30.290000
# 50%    2011.000000       34.050000
# 75%    2017.000000       37.950000
# max    2022.000000       49.930000

# %%
main_df.describe()
# Out:
#               TIME        Cases    Incidence  Extreme Heat  Extreme Precip.  \
# count  1660.000000  1660.000000  1660.000000   1660.000000      1660.000000
# mean   2009.500000     1.444578     0.332791     19.495181         4.616867
# std       5.768019     4.263892     1.367720     11.421112         2.320120
# min    2000.000000     0.000000     0.000000      0.000000         0.000000
# 25%    2004.750000     0.000000     0.000000     10.000000         3.000000
# 50%    2009.500000     0.000000     0.000000     19.000000         4.000000
# 75%    2014.250000     1.000000     0.125374     27.000000         6.000000
# max    2019.000000    57.000000    21.345517     58.000000        13.000000
#
#        Average Monthly Rainfall  Average Temp (F)          Pop.  \
# count               1660.000000       1660.000000  1.660000e+03
# mean                   2.892175         45.922585  1.200378e+05
# std                    0.430769          3.201722  2.633813e+05
# ...

# %%
df.rename(columns = {'Year':'TIME'}, inplace=True)

# %%
df.describe()
# Out:
#               TIME  Total Rainfall
# count  1909.000000     1909.000000
# mean   2011.000000       33.433106
# std       6.634988        7.608103
# min    2000.000000        3.970000
# 25%    2005.000000       30.290000
# 50%    2011.000000       34.050000
# 75%    2017.000000       37.950000
# max    2022.000000       49.930000

# %%
main_df.join(df, on = ['ID', 'TIME'], how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15784\1030289286.py in <module>
# ----> 1 main_df.join(df, on = ['ID', 'TIME'], how = 'inner')
#
# c:\Users\ljens\anaconda3\envs\epi_methods\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9098         """
#    9099         return self._join_compat(
# -> 9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#    9102
#
# c:\Users\ljens\anaconda3\envs\epi_methods\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9136                 right_index=True,
#    9137                 suffixes=(lsuffix, rsuffix),
# -> 9138                 sort=sort,
#    9139             )
#    9140         else:
#
# ...

# %%
main_df.head()
# Out:
#        ID  TIME  Cases  Incidence  Extreme Heat  Extreme Precip.  \
# 0  Alcona  2000      0        0.0             7                2
# 1  Alcona  2001      0        0.0            19                4
# 2  Alcona  2002      0        0.0            25                3
# 3  Alcona  2003      0        0.0            11                3
# 4  Alcona  2004      0        0.0             7                4
#
#    Average Monthly Rainfall  Average Temp (F)   Pop.  Reported Ticks  \
# 0                  2.414167         44.050000  11677             1.0
# 1                  2.378333         46.150000  11665             1.0
# 2                  2.227500         45.125000  11480             0.0
# 3                  2.412500         43.075000  11495             1.0
# 4                  2.560000         43.766667  11459             1.0
#
#    Forest Cover (%)
# 0               NaN
# 1              56.3
# 2               NaN
# 3               NaN
# 4               NaN

# %%
main_df.set_index(['ID', 'TIME'], inplace = True)

# %%
df.set_index(['ID', 'TIME'], inplace=True)

# %%
main_df.join(df, how='inner')
# Out:
# Empty DataFrame
# Columns: [Cases, Incidence, Extreme Heat, Extreme Precip., Average Monthly Rainfall, Average Temp (F), Pop., Reported Ticks, Forest Cover (%), Total Rainfall]
# Index: []

# %%
main_df.head()
# Out:
#              Cases  Incidence  Extreme Heat  Extreme Precip.  \
# ID     TIME
# Alcona 2000      0        0.0             7                2
#        2001      0        0.0            19                4
#        2002      0        0.0            25                3
#        2003      0        0.0            11                3
#        2004      0        0.0             7                4
#
#              Average Monthly Rainfall  Average Temp (F)   Pop.  \
# ID     TIME
# Alcona 2000                  2.414167         44.050000  11677
#        2001                  2.378333         46.150000  11665
#        2002                  2.227500         45.125000  11480
#        2003                  2.412500         43.075000  11495
#        2004                  2.560000         43.766667  11459
#
#              Reported Ticks  Forest Cover (%)
# ID     TIME
# Alcona 2000             1.0               NaN
#        2001             1.0              56.3
# ...

# %%
df.head()
# Out:
#                 Total Rainfall
# ID        TIME
# Alcona    2000           28.97
#           2001           28.54
#           2002           26.73
#           2003           28.95
#           2004           30.72

# %%
df.index == main_df.index
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15784\1212148671.py in <module>
# ----> 1 df.index == main_df.index
#
# c:\Users\ljens\anaconda3\envs\epi_methods\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# c:\Users\ljens\anaconda3\envs\epi_methods\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      30     @unpack_zerodim_and_defer("__eq__")
#      31     def __eq__(self, other):
# ---> 32         return self._cmp_method(other, operator.eq)
#      33
#      34     @unpack_zerodim_and_defer("__ne__")
#
# c:\Users\ljens\anaconda3\envs\epi_methods\lib\site-packages\pandas\core\indexes\base.py in _cmp_method(self, other, op)
#    6040             self
# ...

# %%
main_df.join(df, how='inner', on = ['ID', 'TIME'])
# Out:
# Empty DataFrame
# Columns: [Cases, Incidence, Extreme Heat, Extreme Precip., Average Monthly Rainfall, Average Temp (F), Pop., Reported Ticks, Forest Cover (%), Total Rainfall]
# Index: []

# %%
df.reset_index()['TIME']
# Out:
# 0       2000
# 1       2001
# 2       2002
# 3       2003
# 4       2004
#         ...
# 1904    2018
# 1905    2019
# 1906    2020
# 1907    2021
# 1908    2022
# Name: TIME, Length: 1909, dtype: int64

# %%
main_df.reset_index()['TIME']
# Out:
# 0       2000
# 1       2001
# 2       2002
# 3       2003
# 4       2004
#         ...
# 1655    2015
# 1656    2016
# 1657    2017
# 1658    2018
# 1659    2019
# Name: TIME, Length: 1660, dtype: int64

# %%
main_df.reset_index().join(df.reset_index(), on=['ID', 'TIME'], how='inner', lsuffix = '_left', rsuffix = '_right')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15784\275326151.py in <module>
# ----> 1 main_df.reset_index().join(df.reset_index(), on=['ID', 'TIME'], how='inner', lsuffix = '_left', rsuffix = '_right')
#
# c:\Users\ljens\anaconda3\envs\epi_methods\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9098         """
#    9099         return self._join_compat(
# -> 9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#    9102
#
# c:\Users\ljens\anaconda3\envs\epi_methods\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9136                 right_index=True,
#    9137                 suffixes=(lsuffix, rsuffix),
# -> 9138                 sort=sort,
#    9139             )
# ...

# %%
main_df.merge(df, on = ['ID','TIME'], how='left')
# Out:
#               Cases  Incidence  Extreme Heat  Extreme Precip.  \
# ID      TIME
# Alcona  2000      0   0.000000             7                2
#         2001      0   0.000000            19                4
#         2002      0   0.000000            25                3
#         2003      0   0.000000            11                3
#         2004      0   0.000000             7                4
# ...             ...        ...           ...              ...
# Wexford 2015      0   0.000000            13                4
#         2016      0   0.000000            30                4
#         2017      0   0.000000            10                7
#         2018      0   0.000000            34                3
#         2019      1   0.311478             5                6
#
#               Average Monthly Rainfall  Average Temp (F)   Pop.  \
# ID      TIME
# Alcona  2000                  2.414167         44.050000  11677
# ...

# %%
main_df.head()
# Out:
#              Cases  Incidence  Extreme Heat  Extreme Precip.  \
# ID     TIME
# Alcona 2000      0        0.0             7                2
#        2001      0        0.0            19                4
#        2002      0        0.0            25                3
#        2003      0        0.0            11                3
#        2004      0        0.0             7                4
#
#              Average Monthly Rainfall  Average Temp (F)   Pop.  \
# ID     TIME
# Alcona 2000                  2.414167         44.050000  11677
#        2001                  2.378333         46.150000  11665
#        2002                  2.227500         45.125000  11480
#        2003                  2.412500         43.075000  11495
#        2004                  2.560000         43.766667  11459
#
#              Reported Ticks  Forest Cover (%)
# ID     TIME
# Alcona 2000             1.0               NaN
#        2001             1.0              56.3
# ...

# %%
df.head()
# Out:
#                 Total Rainfall
# ID        TIME
# Alcona    2000           28.97
#           2001           28.54
#           2002           26.73
#           2003           28.95
#           2004           30.72

# %%
df.join(main_df, how='right')
# Out:
#               Total Rainfall  Cases  Incidence  Extreme Heat  Extreme Precip.  \
# ID      TIME
# Alcona  2000             NaN      0   0.000000             7                2
#         2001             NaN      0   0.000000            19                4
#         2002             NaN      0   0.000000            25                3
#         2003             NaN      0   0.000000            11                3
#         2004             NaN      0   0.000000             7                4
# ...                      ...    ...        ...           ...              ...
# Wexford 2015             NaN      0   0.000000            13                4
#         2016             NaN      0   0.000000            30                4
#         2017             NaN      0   0.000000            10                7
#         2018             NaN      0   0.000000            34                3
#         2019             NaN      1   0.311478             5                6
#
# ...

# %%
df.reset_index()['ID'][0].strip()
# Out:
# 'Alcona'

# %%
main_df.reset_index()['ID'][0]
# Out:
# 'Alcona'

# %%
df.reset_index(inplace=True)

# %%
df['ID'] = df['ID'].apply(lambda x: x.strip())

# %%
df['ID'][0]
# Out:
# 'Alcona'

# %%
df.head()
# Out:
#        ID  Year  Total Rainfall
# 0  Alcona  2000           28.97
# 1  Alcona  2001           28.54
# 2  Alcona  2002           26.73
# 3  Alcona  2003           28.95
# 4  Alcona  2004           30.72

# %%
df.rename(columns = {'Year':'TIME'}, inplace=True)

# %%
df= df.set_index(['ID','TIME'])

# %%
df.head()
# Out:
#              Total Rainfall
# ID     TIME
# Alcona 2000           28.97
#        2001           28.54
#        2002           26.73
#        2003           28.95
#        2004           30.72

# %%
main_df.join(df, how='inner')
# Out:
#               Cases  Incidence  Extreme Heat  Extreme Precip.  \
# ID      TIME
# Alcona  2000      0   0.000000             7                2
#         2001      0   0.000000            19                4
#         2002      0   0.000000            25                3
#         2003      0   0.000000            11                3
#         2004      0   0.000000             7                4
# ...             ...        ...           ...              ...
# Wexford 2015      0   0.000000            13                4
#         2016      0   0.000000            30                4
#         2017      0   0.000000            10                7
#         2018      0   0.000000            34                3
#         2019      1   0.311478             5                6
#
#               Average Monthly Rainfall  Average Temp (F)   Pop.  \
# ID      TIME
# Alcona  2000                  2.414167         44.050000  11677
# ...

# %%
all_df = main_df.join(df, how='inner')

# %%
all_df.head()
# Out:
#              Cases  Incidence  Extreme Heat  Extreme Precip.  \
# ID     TIME
# Alcona 2000      0        0.0             7                2
#        2001      0        0.0            19                4
#        2002      0        0.0            25                3
#        2003      0        0.0            11                3
#        2004      0        0.0             7                4
#
#              Average Monthly Rainfall  Average Temp (F)   Pop.  \
# ID     TIME
# Alcona 2000                  2.414167         44.050000  11677
#        2001                  2.378333         46.150000  11665
#        2002                  2.227500         45.125000  11480
#        2003                  2.412500         43.075000  11495
#        2004                  2.560000         43.766667  11459
#
#              Reported Ticks  Forest Cover (%)  Total Rainfall
# ID     TIME
# Alcona 2000             1.0               NaN           28.97
# ...

# %%
all_df.to_csv("C:\\Users\\ljens\\OneDrive\\Documents\\APHA\\data.csv")
